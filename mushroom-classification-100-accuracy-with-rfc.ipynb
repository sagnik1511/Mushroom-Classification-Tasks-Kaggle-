# %% [markdown]
# **This kernel is for those who are new to *data science* or *machine learning* . Please understand each line carefully.**

# %% [markdown]
# **Process of a simple machine learning Task---**
#                                    1. Importing libraries
#                                    2. Reading the Data and visualization
#                                    3. Pre-processing (if needed)
#                                    4. EDA (if needed)
#                                    5. Prediction
#                                    6. Conclusion (if needed)

# %% [markdown]
# # Libraries

# %%
#for visualization purpose and pre-processing

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import random

# for data prediction and creating submission files

from sklearn.model_selection import train_test_split
from sklearn import*
import xgboost as xgb
import keras
import tensorflow as tf
import catboost as cbt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mushroom-classification/mushrooms.csv

# %% [markdown]
# # Reading data and visualization

# %%
df=pd.read_csv('/kaggle/input/mushroom-classification/mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# Name of the columns

# %%
colm=[]
for col in df.columns:
    print(col)
    colm.append(col)
#colm
# Out:
# class
# cap-shape
# cap-surface
# cap-color
# bruises
# odor
# gill-attachment
# gill-spacing
# gill-size
# gill-color
# stalk-shape
# stalk-root
# stalk-surface-above-ring
# stalk-surface-below-ring
# stalk-color-above-ring
# stalk-color-below-ring
# veil-type
# veil-color
# ring-number
# ring-type
# spore-print-color
# population
# habitat

# %% [markdown]
# Clearly visible it is a categorical data. we need it to be numeric for prediction purpose .
# As it is a classification problem we will have to understand the data quality.

# %% [markdown]
# Shape of the dataframe :

# %%
print('shape of the dataframe :',df.shape)
# Out:
# shape of the dataframe : (8124, 23)

# %% [markdown]
# Data is medium in size.
#
# That means we can use many type of classifier to predict the the data or precisely classify .

# %% [markdown]
# # Pre-processing

# %% [markdown]
# As we know the data is categorical we have to initiate with some tasks here -
#             1. Checking leakages
#             2. Filling the leakages  (if present)
#             3. If the data is producing any combination or sequential formation then reshuffling the data by rows
#             4. Numerating the categorical data

# %% [markdown]
# * Leakages

# %%
for j in range(23):
    cnt=0
    for i in range(26):
        cnt+=len(df[df[colm[j]]==chr(i+97)])
    print('no. of leakages in',colm[j],'is :',len(df)-cnt)
# Out:
# no. of leakages in class is : 0
# no. of leakages in cap-shape is : 0
# no. of leakages in cap-surface is : 0
# no. of leakages in cap-color is : 0
# no. of leakages in bruises is : 0
# no. of leakages in odor is : 0
# no. of leakages in gill-attachment is : 0
# no. of leakages in gill-spacing is : 0
# no. of leakages in gill-size is : 0
# no. of leakages in gill-color is : 0
# no. of leakages in stalk-shape is : 0
# no. of leakages in stalk-root is : 2480
# no. of leakages in stalk-surface-above-ring is : 0
# no. of leakages in stalk-surface-below-ring is : 0
# no. of leakages in stalk-color-above-ring is : 0
# no. of leakages in stalk-color-below-ring is : 0
# no. of leakages in veil-type is : 0
# no. of leakages in veil-color is : 0
# no. of leakages in ring-number is : 0
# no. of leakages in ring-type is : 0
# no. of leakages in spore-print-color is : 0
# no. of leakages in population is : 0
# no. of leakages in habitat is : 0

# %% [markdown]
# data is leakage free.
#
# So we have enough data to analyze the model and predict.

# %% [markdown]
# * Data reshuffling

# %% [markdown]
# It is best to shuffle data always. Cause chances of getting a combination after this process are close to zero.

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df=df.sample(frac=1)
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 7239     e         f           s         n       f    n               a
# 7747     e         b           s         g       f    n               f
# 4129     e         f           f         e       t    n               f
# 5055     p         f           f         y       f    f               f
# 6670     p         f           s         n       f    s               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 6120     e         x           s         c       t    n               f
# 2390     e         f           f         n       t    n               f
# 669      e         x           y         w       t    a               f
# 4109     e         f           y         g       t    n               f
# 3604     p         x           y         g       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# After shuffling we have to make the data set numeric to initiate further process.

# %% [markdown]
# * Numeration of categorical data

# %%
def non_num_data(df):             # function to turn all categorical data into numbers
    columns=df.columns.values
    
    for column in columns:
        text_digit_vals={}
        def con_to_int(val):
            return text_digit_vals[val]
        
        if df[column].dtype!=np.int64 and df[column].dtype!=np.float64:
            column_contents=df[column].values.tolist()
            unique_elements=set(column_contents)
            x=0
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    text_digit_vals[unique]=x
                    x+=1
            df[column]=list(map(con_to_int,df[column]))
    return df
non_num_data(df)
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 7239      0          1            3          9        1     8
# 7747      0          5            3          1        1     8
# 4129      0          1            1          0        0     8
# 5055      1          1            1          8        1     2
# 6670      1          1            3          9        1     3
# ...     ...        ...          ...        ...      ...   ...
# 6120      0          0            3          6        0     8
# 2390      0          1            1          9        0     8
# 669       0          0            2          4        0     5
# 4109      0          1            2          1        0     8
# 3604      1          0            2          1        1     2
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 7239                0             1          0          11  ...
# 7747                1             0          0           4  ...
# ...

# %% [markdown]
# # Prediction with RandomForestClassifier

# %% [markdown]
# As the data has been turned numric we can start prediction

# %% [markdown]
# Creating X and Y

# %%
X_df=df.drop('class',1)
y_df=df['class']

# %% [markdown]
# * *Train data* and *Test data* preparation

# %%
X_train,X_test,y_train,y_test=train_test_split(X_df,y_df,test_size=0.2,random_state=0)
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (6499, 22) (6499,) (1625, 22) (1625,)

# %% [markdown]
# Creating model

# %%
model=RandomForestClassifier()
model
# Out:
# RandomForestClassifier()

# %% [markdown]
# Fitting model

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# Creating *prediction* data

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %% [markdown]
# Checking *Accuracy*

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %% [markdown]
# WOW ! That RandomForestClassifier makes an perfect accuracy.

# %% [markdown]
# It is a basic process to use RandomForestClassifier to the dataframe and predict the model .

# %% [markdown]
# Task ends here.

# %% [markdown]
# # *UPVOTE* please to get more tutorials like this .

# %% [markdown]
# **You can join my discoed server where I try to analyze over many datasets: Discord Link : *https://discord.gg/zSK9an6J* (Atlantic Data Studio)**
